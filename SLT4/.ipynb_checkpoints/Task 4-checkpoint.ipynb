# %% [markdown]
# # Importing all requirements

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Create a model

# %%
#create a model using sequential
#add dense layers and activation function

# %%
model = Sequential([
    Dense(units = 32, input_dim =16, activation = 'relu'),
    Dense(units = 16, activation = 'relu'),
    Dense(units = 1, activation = 'sigmoid')
])

# %% [markdown]
# # Importing Dataset

# %%
#import your dataset
train_df = pd.read_csv('train2.csv')
test_df = pd.read_csv('test.csv')

# %% [markdown]
# # Create features and run code

# %%
#create the features and labels of the dataset
#run the code
features = ["Age","Fare","Family_members","1","2","3","male","female","C","Q","S","Master","Miss","Mr","Mrs","Ms"]
X = train_df[features]
Y = train_df["Survived"]

# %% [markdown]
# # Split the dataset

# %%
#Split the dataset into train,test dataset
X_train,y_train,X_test,y_test = train_test_split(X,Y,test_size = 0.20,random_state = 1)

# %% [markdown]
# # Compile the dataset

# %%
#compile your model using optimizers like "SGD","ADAM"
#use model.fit to train 
model.compile(optimizer = "SGD", loss = 'binary_crossentropy', metrics = ["binary_accuracy"])
model_result = model.fit(X,Y, batch_size = 100, epochs = 200, validation_split = 0.2, shuffle = True, verbose = 2)
# Out:
# Epoch 1/200
# 8/8 - 0s - loss: 0.7287 - binary_accuracy: 0.3890 - val_loss: 0.7251 - val_binary_accuracy: 0.2961
# Epoch 2/200
# 8/8 - 0s - loss: 0.7139 - binary_accuracy: 0.3820 - val_loss: 0.7147 - val_binary_accuracy: 0.3296
# Epoch 3/200
# 8/8 - 0s - loss: 0.7057 - binary_accuracy: 0.4087 - val_loss: 0.7054 - val_binary_accuracy: 0.4581
# Epoch 4/200
# 8/8 - 0s - loss: 0.6978 - binary_accuracy: 0.5660 - val_loss: 0.6974 - val_binary_accuracy: 0.5642
# Epoch 5/200
# 8/8 - 0s - loss: 0.6910 - binary_accuracy: 0.6039 - val_loss: 0.6896 - val_binary_accuracy: 0.5698
# Epoch 6/200
# 8/8 - 0s - loss: 0.6844 - binary_accuracy: 0.6222 - val_loss: 0.6831 - val_binary_accuracy: 0.5978
# Epoch 7/200
# 8/8 - 0s - loss: 0.6792 - binary_accuracy: 0.6573 - val_loss: 0.6769 - val_binary_accuracy: 0.6480
# Epoch 8/200
# 8/8 - 0s - loss: 0.6747 - binary_accuracy: 0.6784 - val_loss: 0.6725 - val_binary_accuracy: 0.6425
# Epoch 9/200
# 8/8 - 0s - loss: 0.6714 - binary_accuracy: 0.6812 - val_loss: 0.6693 - val_binary_accuracy: 0.6313
# Epoch 10/200
# 8/8 - 0s - loss: 0.6686 - binary_accuracy: 0.7079 - val_loss: 0.6661 - val_binary_accuracy: 0.6704
# Epoch 11/200
# 8/8 - 0s - loss: 0.6658 - binary_accuracy: 0.7177 - val_loss: 0.6634 - val_binary_accuracy: 0.6816
# Epoch 12/200
# 8/8 - 0s - loss: 0.6634 - binary_accuracy: 0.7247 - val_loss: 0.6610 - val_binary_accuracy: 0.6816
# Epoch 13/200
# 8/8 - 0s - loss: 0.6611 - binary_accuracy: 0.7261 - val_loss: 0.6586 - val_binary_accuracy: 0.6816
# Epoch 14/200
# 8/8 - 0s - loss: 0.6588 - binary_accuracy: 0.7303 - val_loss: 0.6565 - val_binary_accuracy: 0.6927
# Epoch 15/200
# 8/8 - 0s - loss: 0.6567 - binary_accuracy: 0.7317 - val_loss: 0.6545 - val_binary_accuracy: 0.6927
# Epoch 16/200
# 8/8 - 0s - loss: 0.6546 - binary_accuracy: 0.7458 - val_loss: 0.6518 - val_binary_accuracy: 0.7374
# Epoch 17/200
# 8/8 - 0s - loss: 0.6523 - binary_accuracy: 0.7626 - val_loss: 0.6499 - val_binary_accuracy: 0.7374
# Epoch 18/200
# 8/8 - 0s - loss: 0.6502 - binary_accuracy: 0.7683 - val_loss: 0.6474 - val_binary_accuracy: 0.7374
# Epoch 19/200
# 8/8 - 0s - loss: 0.6478 - binary_accuracy: 0.7697 - val_loss: 0.6446 - val_binary_accuracy: 0.7374
# Epoch 20/200
# 8/8 - 0s - loss: 0.6456 - binary_accuracy: 0.7711 - val_loss: 0.6424 - val_binary_accuracy: 0.7374
# Epoch 21/200
# 8/8 - 0s - loss: 0.6434 - binary_accuracy: 0.7739 - val_loss: 0.6400 - val_binary_accuracy: 0.7374
# Epoch 22/200
# 8/8 - 0s - loss: 0.6412 - binary_accuracy: 0.7711 - val_loss: 0.6371 - val_binary_accuracy: 0.7430
# Epoch 23/200
# 8/8 - 0s - loss: 0.6388 - binary_accuracy: 0.7781 - val_loss: 0.6352 - val_binary_accuracy: 0.7430
# Epoch 24/200
# 8/8 - 0s - loss: 0.6369 - binary_accuracy: 0.7837 - val_loss: 0.6328 - val_binary_accuracy: 0.7374
# Epoch 25/200
# 8/8 - 0s - loss: 0.6349 - binary_accuracy: 0.7865 - val_loss: 0.6303 - val_binary_accuracy: 0.7374
# Epoch 26/200
# 8/8 - 0s - loss: 0.6326 - binary_accuracy: 0.7851 - val_loss: 0.6281 - val_binary_accuracy: 0.7374
# Epoch 27/200
# 8/8 - 0s - loss: 0.6306 - binary_accuracy: 0.7879 - val_loss: 0.6259 - val_binary_accuracy: 0.7374
# Epoch 28/200
# 8/8 - 0s - loss: 0.6283 - binary_accuracy: 0.7893 - val_loss: 0.6234 - val_binary_accuracy: 0.7486
# Epoch 29/200
# 8/8 - 0s - loss: 0.6261 - binary_accuracy: 0.7879 - val_loss: 0.6213 - val_binary_accuracy: 0.7486
# Epoch 30/200
# 8/8 - 0s - loss: 0.6240 - binary_accuracy: 0.7893 - val_loss: 0.6187 - val_binary_accuracy: 0.7542
# Epoch 31/200
# 8/8 - 0s - loss: 0.6217 - binary_accuracy: 0.7879 - val_loss: 0.6165 - val_binary_accuracy: 0.7598
# Epoch 32/200
# 8/8 - 0s - loss: 0.6195 - binary_accuracy: 0.7907 - val_loss: 0.6143 - val_binary_accuracy: 0.7709
# Epoch 33/200
# 8/8 - 0s - loss: 0.6174 - binary_accuracy: 0.7907 - val_loss: 0.6119 - val_binary_accuracy: 0.7933
# Epoch 34/200
# 8/8 - 0s - loss: 0.6150 - binary_accuracy: 0.8048 - val_loss: 0.6093 - val_binary_accuracy: 0.7989
# Epoch 35/200
# 8/8 - 0s - loss: 0.6128 - binary_accuracy: 0.7978 - val_loss: 0.6070 - val_binary_accuracy: 0.8045
# Epoch 36/200
# 8/8 - 0s - loss: 0.6105 - binary_accuracy: 0.7992 - val_loss: 0.6043 - val_binary_accuracy: 0.8101
# Epoch 37/200
# 8/8 - 0s - loss: 0.6081 - binary_accuracy: 0.7992 - val_loss: 0.6019 - val_binary_accuracy: 0.8101
# Epoch 38/200
# 8/8 - 0s - loss: 0.6059 - binary_accuracy: 0.7992 - val_loss: 0.5995 - val_binary_accuracy: 0.8101
# Epoch 39/200
# 8/8 - 0s - loss: 0.6037 - binary_accuracy: 0.7978 - val_loss: 0.5971 - val_binary_accuracy: 0.8101
# Epoch 40/200
# 8/8 - 0s - loss: 0.6014 - binary_accuracy: 0.7978 - val_loss: 0.5946 - val_binary_accuracy: 0.8101
# Epoch 41/200
# 8/8 - 0s - loss: 0.5991 - binary_accuracy: 0.7978 - val_loss: 0.5919 - val_binary_accuracy: 0.8101
# Epoch 42/200
# 8/8 - 0s - loss: 0.5967 - binary_accuracy: 0.7978 - val_loss: 0.5895 - val_binary_accuracy: 0.8101
# Epoch 43/200
# 8/8 - 0s - loss: 0.5944 - binary_accuracy: 0.7978 - val_loss: 0.5875 - val_binary_accuracy: 0.8101
# Epoch 44/200
# 8/8 - 0s - loss: 0.5923 - binary_accuracy: 0.7978 - val_loss: 0.5848 - val_binary_accuracy: 0.8101
# Epoch 45/200
# 8/8 - 0s - loss: 0.5899 - binary_accuracy: 0.7978 - val_loss: 0.5825 - val_binary_accuracy: 0.8101
# Epoch 46/200
# 8/8 - 0s - loss: 0.5878 - binary_accuracy: 0.7978 - val_loss: 0.5798 - val_binary_accuracy: 0.8101
# Epoch 47/200
# 8/8 - 0s - loss: 0.5855 - binary_accuracy: 0.7978 - val_loss: 0.5773 - val_binary_accuracy: 0.8101
# Epoch 48/200
# 8/8 - 0s - loss: 0.5833 - binary_accuracy: 0.7978 - val_loss: 0.5747 - val_binary_accuracy: 0.8101
# Epoch 49/200
# 8/8 - 0s - loss: 0.5808 - binary_accuracy: 0.7978 - val_loss: 0.5723 - val_binary_accuracy: 0.8101
# Epoch 50/200
# 8/8 - 0s - loss: 0.5785 - binary_accuracy: 0.7978 - val_loss: 0.5700 - val_binary_accuracy: 0.8101
# Epoch 51/200
# 8/8 - 0s - loss: 0.5762 - binary_accuracy: 0.7992 - val_loss: 0.5674 - val_binary_accuracy: 0.8101
# Epoch 52/200
# 8/8 - 0s - loss: 0.5737 - binary_accuracy: 0.7992 - val_loss: 0.5652 - val_binary_accuracy: 0.8101
# Epoch 53/200
# 8/8 - 0s - loss: 0.5716 - binary_accuracy: 0.7992 - val_loss: 0.5625 - val_binary_accuracy: 0.8101
# Epoch 54/200
# 8/8 - 0s - loss: 0.5694 - binary_accuracy: 0.7992 - val_loss: 0.5599 - val_binary_accuracy: 0.8101
# Epoch 55/200
# 8/8 - 0s - loss: 0.5669 - binary_accuracy: 0.7992 - val_loss: 0.5572 - val_binary_accuracy: 0.8101
# Epoch 56/200
# 8/8 - 0s - loss: 0.5644 - binary_accuracy: 0.7992 - val_loss: 0.5547 - val_binary_accuracy: 0.8101
# Epoch 57/200
# 8/8 - 0s - loss: 0.5619 - binary_accuracy: 0.7992 - val_loss: 0.5523 - val_binary_accuracy: 0.8101
# Epoch 58/200
# 8/8 - 0s - loss: 0.5597 - binary_accuracy: 0.7992 - val_loss: 0.5497 - val_binary_accuracy: 0.8101
# Epoch 59/200
# 8/8 - 0s - loss: 0.5573 - binary_accuracy: 0.7893 - val_loss: 0.5468 - val_binary_accuracy: 0.8101
# Epoch 60/200
# 8/8 - 0s - loss: 0.5549 - binary_accuracy: 0.7992 - val_loss: 0.5439 - val_binary_accuracy: 0.8101
# Epoch 61/200
# 8/8 - 0s - loss: 0.5523 - binary_accuracy: 0.7992 - val_loss: 0.5410 - val_binary_accuracy: 0.8101
# Epoch 62/200
# 8/8 - 0s - loss: 0.5496 - binary_accuracy: 0.8006 - val_loss: 0.5381 - val_binary_accuracy: 0.8101
# Epoch 63/200
# 8/8 - 0s - loss: 0.5468 - binary_accuracy: 0.7907 - val_loss: 0.5356 - val_binary_accuracy: 0.7765
# Epoch 64/200
# 8/8 - 0s - loss: 0.5443 - binary_accuracy: 0.7781 - val_loss: 0.5327 - val_binary_accuracy: 0.7765
# Epoch 65/200
# 8/8 - 0s - loss: 0.5418 - binary_accuracy: 0.7781 - val_loss: 0.5300 - val_binary_accuracy: 0.7765
# Epoch 66/200
# 8/8 - 0s - loss: 0.5393 - binary_accuracy: 0.7795 - val_loss: 0.5273 - val_binary_accuracy: 0.7765
# Epoch 67/200
# 8/8 - 0s - loss: 0.5370 - binary_accuracy: 0.7809 - val_loss: 0.5250 - val_binary_accuracy: 0.7765
# Epoch 68/200
# 8/8 - 0s - loss: 0.5348 - binary_accuracy: 0.7809 - val_loss: 0.5226 - val_binary_accuracy: 0.7765
# Epoch 69/200
# 8/8 - 0s - loss: 0.5329 - binary_accuracy: 0.7809 - val_loss: 0.5199 - val_binary_accuracy: 0.7821
# Epoch 70/200
# 8/8 - 0s - loss: 0.5304 - binary_accuracy: 0.7809 - val_loss: 0.5177 - val_binary_accuracy: 0.7933
# Epoch 71/200
# 8/8 - 0s - loss: 0.5281 - binary_accuracy: 0.7851 - val_loss: 0.5150 - val_binary_accuracy: 0.7933
# Epoch 72/200
# 8/8 - 0s - loss: 0.5258 - binary_accuracy: 0.7851 - val_loss: 0.5123 - val_binary_accuracy: 0.7933
# Epoch 73/200
# 8/8 - 0s - loss: 0.5232 - binary_accuracy: 0.7851 - val_loss: 0.5097 - val_binary_accuracy: 0.7933
# Epoch 74/200
# 8/8 - 0s - loss: 0.5209 - binary_accuracy: 0.7851 - val_loss: 0.5069 - val_binary_accuracy: 0.7933
# Epoch 75/200
# 8/8 - 0s - loss: 0.5188 - binary_accuracy: 0.7851 - val_loss: 0.5042 - val_binary_accuracy: 0.7933
# Epoch 76/200
# 8/8 - 0s - loss: 0.5164 - binary_accuracy: 0.7851 - val_loss: 0.5016 - val_binary_accuracy: 0.7933
# Epoch 77/200
# 8/8 - 0s - loss: 0.5143 - binary_accuracy: 0.7851 - val_loss: 0.4993 - val_binary_accuracy: 0.7933
# Epoch 78/200
# 8/8 - 0s - loss: 0.5124 - binary_accuracy: 0.7851 - val_loss: 0.4968 - val_binary_accuracy: 0.7933
# Epoch 79/200
# 8/8 - 0s - loss: 0.5102 - binary_accuracy: 0.7851 - val_loss: 0.4943 - val_binary_accuracy: 0.7933
# Epoch 80/200
# 8/8 - 0s - loss: 0.5080 - binary_accuracy: 0.7851 - val_loss: 0.4924 - val_binary_accuracy: 0.7933
# Epoch 81/200
# 8/8 - 0s - loss: 0.5063 - binary_accuracy: 0.7851 - val_loss: 0.4899 - val_binary_accuracy: 0.7933
# Epoch 82/200
# 8/8 - 0s - loss: 0.5044 - binary_accuracy: 0.7851 - val_loss: 0.4876 - val_binary_accuracy: 0.7933
# Epoch 83/200
# 8/8 - 0s - loss: 0.5023 - binary_accuracy: 0.7851 - val_loss: 0.4852 - val_binary_accuracy: 0.7933
# Epoch 84/200
# 8/8 - 0s - loss: 0.5004 - binary_accuracy: 0.7851 - val_loss: 0.4831 - val_binary_accuracy: 0.7933
# Epoch 85/200
# 8/8 - 0s - loss: 0.4986 - binary_accuracy: 0.7851 - val_loss: 0.4811 - val_binary_accuracy: 0.7933
# Epoch 86/200
# 8/8 - 0s - loss: 0.4967 - binary_accuracy: 0.7851 - val_loss: 0.4799 - val_binary_accuracy: 0.7933
# Epoch 87/200
# 8/8 - 0s - loss: 0.4954 - binary_accuracy: 0.7851 - val_loss: 0.4785 - val_binary_accuracy: 0.7933
# Epoch 88/200
# 8/8 - 0s - loss: 0.4940 - binary_accuracy: 0.7851 - val_loss: 0.4767 - val_binary_accuracy: 0.7933
# Epoch 89/200
# 8/8 - 0s - loss: 0.4923 - binary_accuracy: 0.7851 - val_loss: 0.4741 - val_binary_accuracy: 0.7933
# Epoch 90/200
# 8/8 - 0s - loss: 0.4906 - binary_accuracy: 0.7851 - val_loss: 0.4722 - val_binary_accuracy: 0.7933
# Epoch 91/200
# 8/8 - 0s - loss: 0.4889 - binary_accuracy: 0.7851 - val_loss: 0.4704 - val_binary_accuracy: 0.7933
# Epoch 92/200
# 8/8 - 0s - loss: 0.4877 - binary_accuracy: 0.7851 - val_loss: 0.4690 - val_binary_accuracy: 0.7933
# Epoch 93/200
# 8/8 - 0s - loss: 0.4863 - binary_accuracy: 0.7851 - val_loss: 0.4671 - val_binary_accuracy: 0.7933
# Epoch 94/200
# 8/8 - 0s - loss: 0.4849 - binary_accuracy: 0.7851 - val_loss: 0.4652 - val_binary_accuracy: 0.7933
# Epoch 95/200
# 8/8 - 0s - loss: 0.4834 - binary_accuracy: 0.7851 - val_loss: 0.4636 - val_binary_accuracy: 0.7933
# Epoch 96/200
# 8/8 - 0s - loss: 0.4821 - binary_accuracy: 0.7851 - val_loss: 0.4623 - val_binary_accuracy: 0.7933
# Epoch 97/200
# 8/8 - 0s - loss: 0.4809 - binary_accuracy: 0.7851 - val_loss: 0.4606 - val_binary_accuracy: 0.7933
# Epoch 98/200
# 8/8 - 0s - loss: 0.4798 - binary_accuracy: 0.7851 - val_loss: 0.4591 - val_binary_accuracy: 0.7933
# Epoch 99/200
# 8/8 - 0s - loss: 0.4786 - binary_accuracy: 0.7851 - val_loss: 0.4580 - val_binary_accuracy: 0.7933
# Epoch 100/200
# 8/8 - 0s - loss: 0.4775 - binary_accuracy: 0.7851 - val_loss: 0.4565 - val_binary_accuracy: 0.7933
# Epoch 101/200
# 8/8 - 0s - loss: 0.4764 - binary_accuracy: 0.7851 - val_loss: 0.4556 - val_binary_accuracy: 0.7933
# Epoch 102/200
# 8/8 - 0s - loss: 0.4754 - binary_accuracy: 0.7851 - val_loss: 0.4536 - val_binary_accuracy: 0.7933
# Epoch 103/200
# 8/8 - 0s - loss: 0.4744 - binary_accuracy: 0.7851 - val_loss: 0.4522 - val_binary_accuracy: 0.7933
# Epoch 104/200
# 8/8 - 0s - loss: 0.4735 - binary_accuracy: 0.7851 - val_loss: 0.4507 - val_binary_accuracy: 0.7933
# Epoch 105/200
# 8/8 - 0s - loss: 0.4725 - binary_accuracy: 0.7851 - val_loss: 0.4493 - val_binary_accuracy: 0.7933
# Epoch 106/200
# 8/8 - 0s - loss: 0.4715 - binary_accuracy: 0.7851 - val_loss: 0.4482 - val_binary_accuracy: 0.7933
# Epoch 107/200
# 8/8 - 0s - loss: 0.4706 - binary_accuracy: 0.7851 - val_loss: 0.4470 - val_binary_accuracy: 0.7933
# Epoch 108/200
# 8/8 - 0s - loss: 0.4698 - binary_accuracy: 0.7851 - val_loss: 0.4457 - val_binary_accuracy: 0.7933
# Epoch 109/200
# 8/8 - 0s - loss: 0.4688 - binary_accuracy: 0.7851 - val_loss: 0.4448 - val_binary_accuracy: 0.7933
# Epoch 110/200
# 8/8 - 0s - loss: 0.4680 - binary_accuracy: 0.7851 - val_loss: 0.4440 - val_binary_accuracy: 0.7933
# Epoch 111/200
# 8/8 - 0s - loss: 0.4674 - binary_accuracy: 0.7865 - val_loss: 0.4431 - val_binary_accuracy: 0.7933
# Epoch 112/200
# 8/8 - 0s - loss: 0.4666 - binary_accuracy: 0.7865 - val_loss: 0.4420 - val_binary_accuracy: 0.7933
# Epoch 113/200
# 8/8 - 0s - loss: 0.4657 - binary_accuracy: 0.7865 - val_loss: 0.4411 - val_binary_accuracy: 0.7933
# Epoch 114/200
# 8/8 - 0s - loss: 0.4649 - binary_accuracy: 0.7879 - val_loss: 0.4403 - val_binary_accuracy: 0.7933
# Epoch 115/200
# 8/8 - 0s - loss: 0.4642 - binary_accuracy: 0.7879 - val_loss: 0.4394 - val_binary_accuracy: 0.7933
# Epoch 116/200
# 8/8 - 0s - loss: 0.4635 - binary_accuracy: 0.7879 - val_loss: 0.4381 - val_binary_accuracy: 0.7933
# Epoch 117/200
# 8/8 - 0s - loss: 0.4632 - binary_accuracy: 0.7865 - val_loss: 0.4373 - val_binary_accuracy: 0.7933
# Epoch 118/200
# 8/8 - 0s - loss: 0.4624 - binary_accuracy: 0.7865 - val_loss: 0.4371 - val_binary_accuracy: 0.7933
# Epoch 119/200
# 8/8 - 0s - loss: 0.4617 - binary_accuracy: 0.7879 - val_loss: 0.4361 - val_binary_accuracy: 0.7933
# Epoch 120/200
# 8/8 - 0s - loss: 0.4610 - binary_accuracy: 0.7879 - val_loss: 0.4354 - val_binary_accuracy: 0.7933
# Epoch 121/200
# 8/8 - 0s - loss: 0.4604 - binary_accuracy: 0.7865 - val_loss: 0.4350 - val_binary_accuracy: 0.7933
# Epoch 122/200
# 8/8 - 0s - loss: 0.4601 - binary_accuracy: 0.7865 - val_loss: 0.4344 - val_binary_accuracy: 0.7933
# Epoch 123/200
# 8/8 - 0s - loss: 0.4594 - binary_accuracy: 0.7879 - val_loss: 0.4333 - val_binary_accuracy: 0.7933
# Epoch 124/200
# 8/8 - 0s - loss: 0.4587 - binary_accuracy: 0.7879 - val_loss: 0.4328 - val_binary_accuracy: 0.7877
# Epoch 125/200
# 8/8 - 0s - loss: 0.4582 - binary_accuracy: 0.7879 - val_loss: 0.4319 - val_binary_accuracy: 0.7877
# Epoch 126/200
# 8/8 - 0s - loss: 0.4576 - binary_accuracy: 0.7879 - val_loss: 0.4310 - val_binary_accuracy: 0.7933
# Epoch 127/200
# 8/8 - 0s - loss: 0.4571 - binary_accuracy: 0.7879 - val_loss: 0.4303 - val_binary_accuracy: 0.7877
# Epoch 128/200
# 8/8 - 0s - loss: 0.4568 - binary_accuracy: 0.7879 - val_loss: 0.4292 - val_binary_accuracy: 0.7933
# Epoch 129/200
# 8/8 - 0s - loss: 0.4563 - binary_accuracy: 0.7879 - val_loss: 0.4286 - val_binary_accuracy: 0.7877
# Epoch 130/200
# 8/8 - 0s - loss: 0.4557 - binary_accuracy: 0.7879 - val_loss: 0.4283 - val_binary_accuracy: 0.7877
# Epoch 131/200
# 8/8 - 0s - loss: 0.4553 - binary_accuracy: 0.7893 - val_loss: 0.4274 - val_binary_accuracy: 0.7877
# Epoch 132/200
# 8/8 - 0s - loss: 0.4548 - binary_accuracy: 0.7893 - val_loss: 0.4268 - val_binary_accuracy: 0.7877
# Epoch 133/200
# 8/8 - 0s - loss: 0.4541 - binary_accuracy: 0.7893 - val_loss: 0.4262 - val_binary_accuracy: 0.7877
# Epoch 134/200
# 8/8 - 0s - loss: 0.4539 - binary_accuracy: 0.7907 - val_loss: 0.4265 - val_binary_accuracy: 0.7877
# Epoch 135/200
# 8/8 - 0s - loss: 0.4536 - binary_accuracy: 0.7907 - val_loss: 0.4260 - val_binary_accuracy: 0.7877
# Epoch 136/200
# 8/8 - 0s - loss: 0.4533 - binary_accuracy: 0.7907 - val_loss: 0.4251 - val_binary_accuracy: 0.7877
# Epoch 137/200
# 8/8 - 0s - loss: 0.4527 - binary_accuracy: 0.7907 - val_loss: 0.4244 - val_binary_accuracy: 0.7877
# Epoch 138/200
# 8/8 - 0s - loss: 0.4523 - binary_accuracy: 0.7907 - val_loss: 0.4233 - val_binary_accuracy: 0.7877
# Epoch 139/200
# 8/8 - 0s - loss: 0.4519 - binary_accuracy: 0.7907 - val_loss: 0.4230 - val_binary_accuracy: 0.7877
# Epoch 140/200
# 8/8 - 0s - loss: 0.4516 - binary_accuracy: 0.7907 - val_loss: 0.4226 - val_binary_accuracy: 0.7877
# Epoch 141/200
# 8/8 - 0s - loss: 0.4513 - binary_accuracy: 0.7907 - val_loss: 0.4226 - val_binary_accuracy: 0.7933
# Epoch 142/200
# 8/8 - 0s - loss: 0.4510 - binary_accuracy: 0.7907 - val_loss: 0.4223 - val_binary_accuracy: 0.7933
# Epoch 143/200
# 8/8 - 0s - loss: 0.4507 - binary_accuracy: 0.7907 - val_loss: 0.4218 - val_binary_accuracy: 0.7933
# Epoch 144/200
# 8/8 - 0s - loss: 0.4503 - binary_accuracy: 0.7907 - val_loss: 0.4214 - val_binary_accuracy: 0.7933
# Epoch 145/200
# 8/8 - 0s - loss: 0.4500 - binary_accuracy: 0.7907 - val_loss: 0.4212 - val_binary_accuracy: 0.7933
# Epoch 146/200
# 8/8 - 0s - loss: 0.4498 - binary_accuracy: 0.7907 - val_loss: 0.4209 - val_binary_accuracy: 0.7933
# Epoch 147/200
# 8/8 - 0s - loss: 0.4495 - binary_accuracy: 0.7907 - val_loss: 0.4200 - val_binary_accuracy: 0.7933
# Epoch 148/200
# 8/8 - 0s - loss: 0.4491 - binary_accuracy: 0.7907 - val_loss: 0.4197 - val_binary_accuracy: 0.7933
# Epoch 149/200
# 8/8 - 0s - loss: 0.4489 - binary_accuracy: 0.7907 - val_loss: 0.4199 - val_binary_accuracy: 0.7933
# Epoch 150/200
# 8/8 - 0s - loss: 0.4487 - binary_accuracy: 0.7907 - val_loss: 0.4193 - val_binary_accuracy: 0.7933
# Epoch 151/200
# 8/8 - 0s - loss: 0.4484 - binary_accuracy: 0.7907 - val_loss: 0.4184 - val_binary_accuracy: 0.7933
# Epoch 152/200
# 8/8 - 0s - loss: 0.4478 - binary_accuracy: 0.7907 - val_loss: 0.4176 - val_binary_accuracy: 0.7933
# Epoch 153/200
# 8/8 - 0s - loss: 0.4476 - binary_accuracy: 0.7907 - val_loss: 0.4173 - val_binary_accuracy: 0.7933
# Epoch 154/200
# 8/8 - 0s - loss: 0.4473 - binary_accuracy: 0.7907 - val_loss: 0.4166 - val_binary_accuracy: 0.7933
# Epoch 155/200
# 8/8 - 0s - loss: 0.4470 - binary_accuracy: 0.7949 - val_loss: 0.4162 - val_binary_accuracy: 0.7933
# Epoch 156/200
# 8/8 - 0s - loss: 0.4467 - binary_accuracy: 0.7907 - val_loss: 0.4155 - val_binary_accuracy: 0.7933
# Epoch 157/200
# 8/8 - 0s - loss: 0.4464 - binary_accuracy: 0.7992 - val_loss: 0.4154 - val_binary_accuracy: 0.7933
# Epoch 158/200
# 8/8 - 0s - loss: 0.4461 - binary_accuracy: 0.7907 - val_loss: 0.4157 - val_binary_accuracy: 0.7933
# Epoch 159/200
# 8/8 - 0s - loss: 0.4460 - binary_accuracy: 0.7907 - val_loss: 0.4155 - val_binary_accuracy: 0.7933
# Epoch 160/200
# 8/8 - 0s - loss: 0.4460 - binary_accuracy: 0.7907 - val_loss: 0.4147 - val_binary_accuracy: 0.7933
# Epoch 161/200
# 8/8 - 0s - loss: 0.4456 - binary_accuracy: 0.7935 - val_loss: 0.4138 - val_binary_accuracy: 0.8268
# Epoch 162/200
# 8/8 - 0s - loss: 0.4453 - binary_accuracy: 0.8104 - val_loss: 0.4132 - val_binary_accuracy: 0.8268
# Epoch 163/200
# 8/8 - 0s - loss: 0.4451 - binary_accuracy: 0.8118 - val_loss: 0.4128 - val_binary_accuracy: 0.8324
# Epoch 164/200
# 8/8 - 0s - loss: 0.4448 - binary_accuracy: 0.8104 - val_loss: 0.4119 - val_binary_accuracy: 0.8268
# Epoch 165/200
# 8/8 - 0s - loss: 0.4446 - binary_accuracy: 0.8104 - val_loss: 0.4115 - val_binary_accuracy: 0.8268
# Epoch 166/200
# 8/8 - 0s - loss: 0.4443 - binary_accuracy: 0.8104 - val_loss: 0.4110 - val_binary_accuracy: 0.8268
# Epoch 167/200
# 8/8 - 0s - loss: 0.4442 - binary_accuracy: 0.8104 - val_loss: 0.4106 - val_binary_accuracy: 0.8268
# Epoch 168/200
# 8/8 - 0s - loss: 0.4439 - binary_accuracy: 0.8104 - val_loss: 0.4102 - val_binary_accuracy: 0.8268
# Epoch 169/200
# 8/8 - 0s - loss: 0.4438 - binary_accuracy: 0.8104 - val_loss: 0.4102 - val_binary_accuracy: 0.8268
# Epoch 170/200
# 8/8 - 0s - loss: 0.4435 - binary_accuracy: 0.8104 - val_loss: 0.4096 - val_binary_accuracy: 0.8268
# Epoch 171/200
# 8/8 - 0s - loss: 0.4433 - binary_accuracy: 0.8104 - val_loss: 0.4093 - val_binary_accuracy: 0.8268
# Epoch 172/200
# 8/8 - 0s - loss: 0.4432 - binary_accuracy: 0.8104 - val_loss: 0.4090 - val_binary_accuracy: 0.8268
# Epoch 173/200
# 8/8 - 0s - loss: 0.4429 - binary_accuracy: 0.8104 - val_loss: 0.4086 - val_binary_accuracy: 0.8268
# Epoch 174/200
# 8/8 - 0s - loss: 0.4427 - binary_accuracy: 0.8104 - val_loss: 0.4086 - val_binary_accuracy: 0.8268
# Epoch 175/200
# 8/8 - 0s - loss: 0.4424 - binary_accuracy: 0.8104 - val_loss: 0.4082 - val_binary_accuracy: 0.8212
# Epoch 176/200
# 8/8 - 0s - loss: 0.4424 - binary_accuracy: 0.8104 - val_loss: 0.4079 - val_binary_accuracy: 0.8212
# Epoch 177/200
# 8/8 - 0s - loss: 0.4421 - binary_accuracy: 0.8090 - val_loss: 0.4078 - val_binary_accuracy: 0.8212
# Epoch 178/200
# 8/8 - 0s - loss: 0.4421 - binary_accuracy: 0.8090 - val_loss: 0.4082 - val_binary_accuracy: 0.8212
# Epoch 179/200
# 8/8 - 0s - loss: 0.4420 - binary_accuracy: 0.8104 - val_loss: 0.4070 - val_binary_accuracy: 0.8212
# Epoch 180/200
# 8/8 - 0s - loss: 0.4416 - binary_accuracy: 0.8104 - val_loss: 0.4061 - val_binary_accuracy: 0.8212
# Epoch 181/200
# 8/8 - 0s - loss: 0.4414 - binary_accuracy: 0.8090 - val_loss: 0.4060 - val_binary_accuracy: 0.8212
# Epoch 182/200
# 8/8 - 0s - loss: 0.4412 - binary_accuracy: 0.8090 - val_loss: 0.4059 - val_binary_accuracy: 0.8212
# Epoch 183/200
# 8/8 - 0s - loss: 0.4410 - binary_accuracy: 0.8104 - val_loss: 0.4058 - val_binary_accuracy: 0.8212
# Epoch 184/200
# 8/8 - 0s - loss: 0.4409 - binary_accuracy: 0.8104 - val_loss: 0.4056 - val_binary_accuracy: 0.8212
# Epoch 185/200
# 8/8 - 0s - loss: 0.4406 - binary_accuracy: 0.8118 - val_loss: 0.4054 - val_binary_accuracy: 0.8212
# Epoch 186/200
# 8/8 - 0s - loss: 0.4405 - binary_accuracy: 0.8118 - val_loss: 0.4051 - val_binary_accuracy: 0.8212
# Epoch 187/200
# 8/8 - 0s - loss: 0.4403 - binary_accuracy: 0.8104 - val_loss: 0.4049 - val_binary_accuracy: 0.8212
# Epoch 188/200
# 8/8 - 0s - loss: 0.4401 - binary_accuracy: 0.8104 - val_loss: 0.4042 - val_binary_accuracy: 0.8212
# Epoch 189/200
# 8/8 - 0s - loss: 0.4400 - binary_accuracy: 0.8118 - val_loss: 0.4037 - val_binary_accuracy: 0.8212
# Epoch 190/200
# 8/8 - 0s - loss: 0.4400 - binary_accuracy: 0.8118 - val_loss: 0.4036 - val_binary_accuracy: 0.8212
# Epoch 191/200
# 8/8 - 0s - loss: 0.4398 - binary_accuracy: 0.8104 - val_loss: 0.4032 - val_binary_accuracy: 0.8212
# Epoch 192/200
# 8/8 - 0s - loss: 0.4397 - binary_accuracy: 0.8118 - val_loss: 0.4030 - val_binary_accuracy: 0.8212
# Epoch 193/200
# 8/8 - 0s - loss: 0.4396 - binary_accuracy: 0.8104 - val_loss: 0.4028 - val_binary_accuracy: 0.8212
# Epoch 194/200
# 8/8 - 0s - loss: 0.4394 - binary_accuracy: 0.8104 - val_loss: 0.4030 - val_binary_accuracy: 0.8156
# Epoch 195/200
# 8/8 - 0s - loss: 0.4392 - binary_accuracy: 0.8104 - val_loss: 0.4028 - val_binary_accuracy: 0.8156
# Epoch 196/200
# 8/8 - 0s - loss: 0.4391 - binary_accuracy: 0.8104 - val_loss: 0.4029 - val_binary_accuracy: 0.8156
# Epoch 197/200
# 8/8 - 0s - loss: 0.4391 - binary_accuracy: 0.8104 - val_loss: 0.4021 - val_binary_accuracy: 0.8156
# Epoch 198/200
# 8/8 - 0s - loss: 0.4388 - binary_accuracy: 0.8104 - val_loss: 0.4016 - val_binary_accuracy: 0.8156
# Epoch 199/200
# 8/8 - 0s - loss: 0.4388 - binary_accuracy: 0.8104 - val_loss: 0.4014 - val_binary_accuracy: 0.8156
# Epoch 200/200
# 8/8 - 0s - loss: 0.4387 - binary_accuracy: 0.8104 - val_loss: 0.4010 - val_binary_accuracy: 0.8156

# %% [markdown]
# # Prediction

# %%
#use model.predict to predict the survival rate on the test dataset and print the predictions
#Try to understand what does these numbers in predict means
predict = model.predict(X_test)
predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MEETME~1\AppData\Local\Temp/ipykernel_19668/1848846355.py in <module>
#       1 #use model.predict to predict the survival rate on the test dataset and print the predictions
#       2 #Try to understand what does these numbers in predict means
# ----> 3 predict = model.predict(X_test)
#       4 predict
#
# C:\Python39\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749           for step in data_handler.steps():
#    1750             callbacks.on_predict_batch_begin(step)
# -> 1751             tmp_batch_outputs = self.predict_function(iterator)
#    1752             if data_handler.should_sync:
#    1753               context.async_wait()
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     757     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     758     self._concrete_stateful_fn = (
# --> 759         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     760             *args, **kwds))
#     761
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3064       args, kwargs = None, None
#    3065     with self._lock:
# -> 3066       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3067     return graph_function
#    3068
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
# -> 3463           graph_function = self._create_graph_function(args, kwargs)
#    3464           self._function_cache.primary[cache_key] = graph_function
#    3465
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3296     arg_names = base_arg_names + missing_arg_names
#    3297     graph_function = ConcreteFunction(
# -> 3298         func_graph_module.func_graph_from_py_func(
#    3299             self._name,
#    3300             self._python_function,
#
# C:\Python39\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# C:\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# C:\Python39\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     992           except Exception as e:  # pylint:disable=broad-except
#     993             if hasattr(e, "ag_error_metadata"):
# --> 994               raise e.ag_error_metadata.to_exception(e)
#     995             else:
#     996               raise
#
# ValueError: in user code:
#
#     C:\Python39\lib\site-packages\keras\engine\training.py:1586 predict_function  *
#         return step_function(self, iterator)
#     C:\Python39\lib\site-packages\keras\engine\training.py:1576 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1286 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2849 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3632 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Python39\lib\site-packages\keras\engine\training.py:1569 run_step  **
#         outputs = model.predict_step(data)
#     C:\Python39\lib\site-packages\keras\engine\training.py:1537 predict_step
#         return self(x, training=False)
#     C:\Python39\lib\site-packages\keras\engine\base_layer.py:1020 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Python39\lib\site-packages\keras\engine\input_spec.py:250 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 16 but received input with shape (None, 1)
